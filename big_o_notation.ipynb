# %% [markdown]
# # Big O Notation

# %% [markdown]
# ## 1.
#
# Title your chart "Big O Notation"
#
# Label your x axis "Elements"
#
# Label your y axis "Operations"
#
# Label your curves or make a legend for the curves
#
# Use LaTex notation where possible
#
# Curves to graph:
#
# $y=0n+1$ and label the curve "O(1)"
#
# $y=log(n)$and label the curve "O(log n)"
#
# $y=n$ and label the curve "O(n)"
#
# $y=n∗log(n)$and label it "O(n log n)"
#
# $y=n^2$ and label it "O(n^2)"
#
# $y=2^n$ and label it "O(2^n)"
#
# $y=n!$ and label it "O(n!)"
#
# $y=n^n$ and label it "O(n^n)"

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
n=[n for n in range(1,100,10)]
y1=[(0 * n) + 1 for n in n]
y2=[np.log(n) for n in n]
y3=[n for n in n]
y4=[(n * np.log(n)) for n in n]
y5=[n ** 2 for n in n]
y6=[2 ** n for n in n]
y7=[np.math.factorial(n) for n in n]
y8=[n ** n for n in n]

plt.plot(n,y1,c='violet',label='$y=O(1)$')
plt.plot(n,y2,c='indigo',label='$O(\log n)$')
plt.plot(n,y3,c='blue',label='$O(n)$')
plt.plot(n,y4,c='green',label='$O(n \log n)$')
plt.plot(n,y5,c='yellow',label='$O(n^2)$')
plt.plot(n,y6,c='orange',label='$O(2^n)$')
plt.plot(n,y7,c='red',label='$O!$')
plt.plot(n,y8,c='crimson',label='$O(n^n)$')

plt.ylim(0,200)
plt.xlim(-1,90)

plt.title('Big O Notation')

plt.xlabel('Elements')
plt.ylabel('Operations')

plt.legend()

plt.show()

# %%
## (x,y) values for the letter Z
x=[1,2]
y=[(0 * x) + 1 for x in x]
y1=[x ** x for x in x]
y2=[(0 * x) + 4 for x in x]

# plotting horizontal lines in 'L'
plt.hlines(y=1,xmin=-0.5,xmax=0.5,colors='black')

# plotting vertical lines in 'L' and 'I'
plt.vlines(x=0.75,ymin=1,ymax=4,colors='black',linewidth=2)
plt.vlines(x=-0.5,ymin=1,ymax=4,colors='black',linewidth=2)

plt.plot(x,y,c='black')
plt.plot(x,y1,c='black')
plt.plot(x,y2,c='black')

plt.title('Liz')

plt.show()
