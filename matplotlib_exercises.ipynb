# %% [markdown]
# # Matplotlib Exercises

# %%
import matplotlib.pyplot as plt
import numpy as np

#Changes the default setting to produce higher resolution images
#%config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 1.
# Use matplotlib to plot the following equation:
#
# $y = x^2 − x + 2$
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = [x for x in range(-2, 11)]
y = [((x ** 2 - x) + 2) for x in x]


plt.plot(x,y)

plt.title('$y=x^2 - x + 2$')

plt.xlabel('x')
plt.ylabel('y')


plt.annotate('Origin', xy=(0,0))

#Additional arguments for annotate the cleans up where the annotation is located and adds arrow.
#plt.annotate('Origin',xy=(0,0), xytext=(0,300), arrowprops ={})

plt.show()

#Saves an image of figure.
#plt.savefig('figure1.png')

# %% [markdown]
# ## 2.
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# $y = √x$
#
# $y = x^3$
#
# $y = 2^x$
#
# $y = 1/(x+1)$
#
# You can use functions from the math module to help implement some of the equations above.

# %%
x=[x for x in range(0,10)]
y=[(x ** 0.5) for x in x]

plt.plot(x,y)

plt.title('$y=\sqrt{x}$')

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
x=[x for x in range(0,10)]
y=[x ** 3 for x in x]

plt.plot(x,y)

plt.title('$y=x^3$')

plt.xlabel('x')
plt.ylabel('y')

#Changes the values on the xticks
#plt.xticks(range(0,20,5))

plt.show()

# %%
x=[x for x in range(0,10)]

#Different way to generate smaller numbers
#x=[x * 0.1 for x in range(0,150)]

y=[(2 ** x) for x in x]

plt.plot(x,y)

plt.title('$y=2^x$')

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
x=[x for x in range(0,26)]
y=[(1/(x+1)) for x in x]

plt.plot(x,y)

plt.title('$y=1/(x + 1)$')

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ## 3.
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x=[x for x in range(0,10)]


y1=[(x ** 0.5) for x in x]
y2=[(x ** 3) for x in x]
y3=[(2 ** x) for x in x]
y4=[(1/(x+1)) for x in x]

plt.figure(figsize=(8,8))
plt.suptitle('Equations')

plt.subplot(221)
plt.plot(x,y1)
plt.title('$y=\sqrt{x}$')

plt.subplot(222)
plt.plot(x,y2)
plt.title('$y=x^3$')

plt.subplot(223)
plt.plot(x,y3)
plt.title('$y=2^x$')

plt.subplot(224)
plt.plot(x,y4)
plt.title('$y=1/(x 1)$')

plt.show()

# %% [markdown]
# ## 4.
# Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x=[x for x in range(0,10)]


y1=[(x ** 0.5) for x in x]
y2=[(x ** 3) for x in x]
y3=[(2 ** x) for x in x]
y4=[(1/(x+1)) for x in x]

#adding alpha argument to .plot adds transparency to lines

plt.plot(x,y1,c='blue',label='$y=\sqrt{x}$')
plt.plot(x,y2,c='red',label='$y=x^3$')
plt.plot(x,y3,c='green',label='$y=2^x$')
plt.plot(x,y4,c='orange',label='$y=1/(x 1)$')

plt.title('Equations')

plt.legend()

plt.ylim(0.0,750)

plt.show()

# %%
##OOB for Matplotlib
#Saving list-like variables where it makes it easy to make similar changes across all the subplots.

#fig, ax = plt.subplots()
#ax.plot(xy)

#fig, axs = plt.subplots(2)
#axs[0].plot(x,y)
#axs[1].plot(x2,y2)

#When using this, some method and arguments names change.
